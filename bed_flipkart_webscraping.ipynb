# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import rishiwebscrapfunctions as rws

# %%
a=rws.sdf(rws.find_wood
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=2"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=3"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=4"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=5"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=6"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=7"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=8"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=9"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=10"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=11"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=12"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=13"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=14"
          ,"https://www.flipkart.com/furniture/beds/beds/pr?count=40&p%5B%5D=facets.bed_size%255B%255D%3DKing&sid=wwe%2F7p7%2F4yf&otracker=clp_banner_1_9.bannerX3.BANNER_beds-store_5FE3D6ZWBO&fm=neo%2Fmerchandising&iid=M_ab6f04ad-63e4-48aa-93a6-e4902102e203_9.5FE3D6ZWBO&ppt=clp&ppn=beds-store&ssid=j0g2d6bqkg0000001574854197290&page=15")

# %%
a
# Out:
#                                                   name    price  peoplerat  \
# 0    crystal furnitech skyler engineered wood king bed  13772.0      591.0
# 1       crystal furnitech engineered wood king box bed  25117.0        3.0
# 2    flipkart perfect homes opus engineered wood ki...  12990.0     7789.0
# 3                  furniturekraft nancy metal king bed   7290.0     1640.0
# 4    flipkart perfect homes carol engineered wood k...  10490.0     6178.0
# ..                                                 ...      ...        ...
# 562           vintej home sheesham wood solid king bed  24390.0        0.0
# 563              hometown engineered wood king box bed  20540.0      139.0
# 564                balaji sheesham wood solid king bed  27190.0        5.0
# 565           saffron art sheesham wood solid king bed  23085.0        0.0
# 566  godrej interio apex engineered wood king drawe...  32733.0        0.0
#
#      assured
# 0        0.0
# 1        0.0
# 2        1.0
# ...

# %%
a.describe()
# Out:
#                price    peoplerat     assured
# count     567.000000   567.000000  567.000000
# mean    32085.160494   222.377425    0.285714
# std     16277.570968   879.132154    0.452153
# min      6500.000000     0.000000    0.000000
# 25%     20555.000000     0.000000    0.000000
# 50%     26975.000000     0.000000    0.000000
# 75%     39885.000000    17.500000    1.000000
# max    145000.000000  7789.000000    1.000000

# %%
sns.regplot(data=a,x='price',y='peoplerat')
plt.show()

# %%
a.hist()
plt.show()

# %%
a['price'].hist()
plt.xlim([5000,50000])
plt.show()

# %%
plt.figure(figsize=(12,7.5))
plt.scatter(a['price'],a['peoplerat'])
plt.xlim([6000,26000])
plt.show()

# %%
a[a['peoplerat']>1000]
# Out:
#                                                   name    price  peoplerat  \
# 2    flipkart perfect homes opus engineered wood ki...  12990.0     7789.0
# 3                  furniturekraft nancy metal king bed   7290.0     1640.0
# 4    flipkart perfect homes carol engineered wood k...  10490.0     6178.0
# 5    flipkart perfect homes rhapsody engineered woo...  15990.0     2365.0
# 7    flipkart perfect homes waltz engineered wood k...  14490.0     5286.0
# 9    flipkart perfect homes waltz engineered wood k...  14490.0     5286.0
# 10   hometown bali bolton engineered wood king box bed  20555.0     2145.0
# 12   flipkart perfect homes rhapsody engineered woo...  15990.0     3817.0
# 14          hometown alex engineered wood king box bed  19999.0     1108.0
# 16   flipkart perfect homes rhapsody engineered woo...  15990.0     2365.0
# 18    spacewood mayflower engineered wood king box bed  18990.0     5670.0
# ...
